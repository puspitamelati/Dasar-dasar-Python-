# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# %%
A=np.arange(0,2*pi,0.1)

# %%
B=2*np.cos(A)

# %%
C=np.sin(A)

# %%
plt.plot(A)
plt.plot(B)
plt.plot(C)
plt.grid('True',which='both')
plt.axhline(y=0)

# %%
import numpy as np
import matplotlib.pyplot as plt 
from datetime import datetime

# %%
import csv

# %%
filename = 'C:/Users/puspi/Downloads/72565003017.csv'

# %%
highs = []
date = []
with open (filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
        
    for data in reader :
        high = int(float(data[6].lstrip())) 
        current_date = datetime.strptime(data[1], '%Y-%m-%d')
        highs.append(high)
        date.append(current_date)
    
print(highs)

plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(date, highs)
plt.title("Daily high temperatures, July 2018", fontsize=24)
plt.xlabel('date', fontsize = 16)
fig.autofmt_xdate()
plt.ylabel('Temperatur(F)', fontsize = 16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# [11, 21, 31, 34, 36, 40, 39, 33, 48, 49, 31, 35, 31, 35, 24, 10, 27, 41, 49, 43, 26, 26, 29, 29, 42, 35, 30, 35, 34, 47, 43, 27, 31, 43, 29, 36, 27, 33, 46, 36, 15, 18, 20, 30, 45, 43, 24, 38, 48, 20, 5, 8, 16, 20, 26, 27, 34, 38, 36, 33, 45, 54, 55, 35, 31, 30, 40, 52, 47, 32, 35, 40, 46, 51, 42, 42, 44, 35, 36, 43, 53, 60, 49, 50, 42, 34, 38, 34, 39, 46, 33, 50, 43, 40, 51, 38, 31, 53, 45, 50, 63, 58, 44, 38, 42, 50, 61, 41, 44, 50, 34, 43, 51, 41, 42, 51, 51, 58, 66, 61, 54, 46, 43, 50, 59, 63, 64, 65, 62, 67, 62, 54, 53, 55, 58, 64, 67, 61, 49, 46, 56, 63, 64, 68, 71, 74, 74, 62, 61, 65, 69, 76, 64, 64, 72, 78, 77, 76, 78, 75, 79, 71, 69, 76, 82, 78, 73, 66, 61, 67, 63, 67, 71, 71, 63, 63, 75, 83, 85, 85, 69, 65, 77, 79, 76, 74, 72, 80, 81, 80, 81, 80, 76, 73, 79, 73, 67, 72, 76, 80, 80, 82, 81, 71, 70, 71, 67, 68, 64, 65, 66, 68, 71, 73, 75, 76, 76, 70, 69, 69, 71, 74, 75, 75, 71, 70, 71, 72, 73, 68, 62, 60, 63, 63, 73, 76, 76, 77, 77, 67, 67, 75, 75, 69, 67, 69, 68, 63, 61, 60, 65, 72, 73, 76, 75, 78, 76, 74, 77, 77, 75, 74, 66, 61, 67, 70, 67, 55, 53, 61, 50, 53, 52, 50, 63, 71, 56, 55, 44, 43, 39, 36, 34, 37, 43, 50, 28, 28, 39, 47, 52, 54, 51, 55, 57, 54, 53, 52, 54, 57, 53, 60, 44, 36, 40, 45, 48, 39, 45, 39, 34, 31, 28, 40, 30, 21, 27, 42, 47, 41, 32, 27, 34, 35, 42, 45, 45, 39, 31, 30, 40, 49, 40, 31, 32, 27, 27, 26, 30, 23, 26, 29, 30, 36, 44, 40, 33, 33, 40, 40, 40, 44, 42, 32, 40, 34, 28, 36, 31, 27, 23, 16, 17, 34, 23]

# %%
for index, column_header in enumerate (header_row) :
    print(index, column_header)
# Out:
# 0 STATION
# 1 DATE
# 2 LATITUDE
# 3 LONGITUDE
# 4 ELEVATION
# 5 NAME
# 6 TEMP
# 7 TEMP_ATTRIBUTES
# 8 DEWP
# 9 DEWP_ATTRIBUTES
# 10 SLP
# 11 SLP_ATTRIBUTES
# 12 STP
# 13 STP_ATTRIBUTES
# 14 VISIB
# 15 VISIB_ATTRIBUTES
# 16 WDSP
# 17 WDSP_ATTRIBUTES
# 18 MXSPD
# 19 GUST
# 20 MAX
# 21 MAX_ATTRIBUTES
# 22 MIN
# 23 MIN_ATTRIBUTES
# 24 PRCP
# 25 PRCP_ATTRIBUTES
# 26 SNDP
# 27 FRSHTT
